# %%
# %load_ext autoreload
# %autoreload 2

import torch
from torch import nn

import numpy as np
from sklearn.model_selection import train_test_split

from ModelHelper2 import *
from ModelHelper2 import myNeural

from Dataset import DatasetRandom

from hyperopt import hp
from hyperopt import fmin, tpe, hp

from ray import tune
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Loading Data

# %%
trainData = DatasetRandom(size = 10000)

testData = DatasetRandom(size = 2000)

# %% [markdown]
# # Hyper-Parameter Tunning

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %% [markdown]
# # Single Model Trial

# %%
defaultConfig = {
    # 'input_shape':(20,20),
    'hidden_size': 300,
    'act_func_1': nn.ReLU,
    'act_func_2': nn.ReLU,
    
    'lossFunction': nn.BCEWithLogitsLoss, 
    'optimiser': torch.optim.SGD, 'lr': 0.1,
    'epoch': 2, 'batch_size': 128,
}

# %%
singleModel = myNeural(defaultConfig)

# %%
singleModel
# Out:
# myNeural(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (stack): Sequential(
#     (0): Linear(in_features=400, out_features=300, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=300, out_features=300, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )

# %%
singleModel.optimise(trainData, testData, 
                     defaultConfig,
                    hideEpochProgressBar=False,
                    hideBatchProgressBar=False)
# Out:
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Batch'), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), ma…
# HBox(children=(HTML(value='Batch'), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), ma…

# %%
singleModel.plotTraining()

# %% [markdown]
# # Hyper-Parameter Tuning

# %%
paramSpace = space = {
    # model parameters
    'hidden_size': hp.randint('hidden_size', 400, 512),
    'act_func_1': hp.choice('act_func_1', [nn.ReLU, nn.LeakyReLU, nn.Sigmoid, nn.Tanh]),
    'act_func_2': hp.choice('act_func_2', [nn.ReLU, nn.LeakyReLU, nn.Sigmoid, nn.Tanh]),
    
    # trainer parameters
    # 'optimiser': hp.choice('optimiser', [torch.optim.SGD, torch.optim.Adam, torch.optim.LBFGS]),
    'lr' : hp.uniform('lr', 0.1, 1.5),
    'epoch': 1+ hp.randint('epoch', 25),
    'batch_size': 1 + hp.randint('batch_size', 512),
}

# %%
myNeural.hyperTuner(trainData, testData, paramSpace,
                   searchMaxConcurrent = 1)
# Out:
# 2021-05-26 15:43:34,380	INFO registry.py:64 -- Detected unknown callable for trainable. Converting to class.
# == Status ==<br>Memory usage on this node: 10.8/16.0 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None<br>Resources requested: 0/12 CPUs, 0/0 GPUs, 0.0/4.85 GiB heap, 0.0/2.43 GiB objects<br>Result logdir: /Users/shaominliu/ray_results/fitTrain_2021-05-26_15-43-34<br>Number of trials: 1/50 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name       </th><th>status  </th><th>loc  </th><th>act_func_1                                   </th><th>act_func_2                                     </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  epoch</th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">      lr</th></tr>
# </thead>
# <tbody>
# <tr><td>fitTrain_13090c22</td><td>PENDING </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;</td><td>&lt;class &#x27;torch.nn.modules.activation.LeakyReLU&#x27;&gt;</td><td style="text-align: right;">         460</td><td style="text-align: right;">     18</td><td style="text-align: right;">          502</td><td style="text-align: right;">0.399176</td></tr>
# </tbody>
# </table><br><br>
# (pid=64370) 2021-05-26 15:43:38,004	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=64370) Traceback (most recent call last):
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=64370)     self._entrypoint()
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=64370)     return self._trainable_func(self.config, self._status_reporter,
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=64370)     output = fn()
# (pid=64370)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=64370)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=64370)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=64370)     trainLoader = DataLoader(trainData,
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=64370)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=64370)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=64370)     return len(self.data_source)
# (pid=64370) TypeError: object of type 'NoneType' has no len()
# (pid=64370) Exception in thread Thread-2:
# (pid=64370) Traceback (most recent call last):
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# (pid=64370)     self.run()
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 267, in run
# (pid=64370)     raise e
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=64370)     self._entrypoint()
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=64370)     return self._trainable_func(self.config, self._status_reporter,
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=64370)     output = fn()
# (pid=64370)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=64370)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=64370)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=64370)     trainLoader = DataLoader(trainData,
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=64370)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=64370)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=64370)     return len(self.data_source)
# (pid=64370) TypeError: object of type 'NoneType' has no len()
# (pid=64371) 2021-05-26 15:43:38,004	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=64371) Traceback (most recent call last):
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=64371)     self._entrypoint()
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=64371)     return self._trainable_func(self.config, self._status_reporter,
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=64371)     output = fn()
# (pid=64371)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=64371)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=64371)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=64371)     trainLoader = DataLoader(trainData,
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=64371)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=64371)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=64371)     return len(self.data_source)
# (pid=64371) TypeError: object of type 'NoneType' has no len()
# (pid=64371) Exception in thread Thread-2:
# (pid=64371) Traceback (most recent call last):
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# (pid=64371)     self.run()
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 267, in run
# (pid=64371)     raise e
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=64371)     self._entrypoint()
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=64371)     return self._trainable_func(self.config, self._status_reporter,
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=64371)     output = fn()
# (pid=64371)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=64371)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=64371)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=64371)     trainLoader = DataLoader(trainData,
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=64371)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=64371)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=64371)     return len(self.data_source)
# (pid=64371) TypeError: object of type 'NoneType' has no len()
# 2021-05-26 15:43:38,210	ERROR trial_runner.py:732 -- Trial fitTrain_13090c22: Error processing event.
# Traceback (most recent call last):
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trial_runner.py", line 702, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/ray_trial_executor.py", line 686, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 47, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/worker.py", line 1481, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=64370, ip=192.168.1.254)
#   File "python/ray/_raylet.pyx", line 505, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 449, in ray._raylet.execute_task.function_executor
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/function_manager.py", line 556, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 173, in train_buffered
#     result = self.train()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 232, in train
#     result = self.step()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 366, in step
#     self._report_thread_runner_error(block=True)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 512, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=64370, ip=192.168.1.254)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
#     self._entrypoint()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
#     output = fn()
#   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
#     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
#   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
#     trainLoader = DataLoader(trainData,
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
#     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
#     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
#     return len(self.data_source)
# TypeError: object of type 'NoneType' has no len()
# 2021-05-26 15:43:38,232	ERROR trial_runner.py:732 -- Trial fitTrain_132a4ac2: Error processing event.
# Traceback (most recent call last):
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trial_runner.py", line 702, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/ray_trial_executor.py", line 686, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 47, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/worker.py", line 1481, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=64371, ip=192.168.1.254)
#   File "python/ray/_raylet.pyx", line 505, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 449, in ray._raylet.execute_task.function_executor
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/function_manager.py", line 556, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 173, in train_buffered
#     result = self.train()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 232, in train
#     result = self.step()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 366, in step
#     self._report_thread_runner_error(block=True)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 512, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=64371, ip=192.168.1.254)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
#     self._entrypoint()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
#     output = fn()
#   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
#     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
#   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
#     trainLoader = DataLoader(trainData,
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
#     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
#     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
#     return len(self.data_source)
# TypeError: object of type 'NoneType' has no len()
# Result for fitTrain_13090c22:
#   {}
#
# Result for fitTrain_132a4ac2:
#   {}
# (pid=64370) Traceback (most recent call last):
# (pid=64370)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=64370)   File "python/ray/_raylet.pyx", line 495, in ray._raylet.execute_task
# (pid=64370)   File "python/ray/_raylet.pyx", line 505, in ray._raylet.execute_task
# (pid=64370)   File "python/ray/_raylet.pyx", line 449, in ray._raylet.execute_task.function_executor
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/function_manager.py", line 556, in actor_method_executor
# (pid=64370)     return method(__ray_actor, *args, **kwargs)
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 173, in train_buffered
# (pid=64370)     result = self.train()
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 232, in train
# (pid=64370)     result = self.step()
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 366, in step
# (pid=64370)     self._report_thread_runner_error(block=True)
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 512, in _report_thread_runner_error
# (pid=64370)     raise TuneError(
# (pid=64370) ray.tune.error.TuneError: Trial raised an exception. Traceback:
# (pid=64370) Traceback (most recent call last):
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=64370)     self._entrypoint()
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=64370)     return self._trainable_func(self.config, self._status_reporter,
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=64370)     output = fn()
# (pid=64370)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=64370)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=64370)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=64370)     trainLoader = DataLoader(trainData,
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=64370)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=64370)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=64370)     return len(self.data_source)
# (pid=64370) TypeError: object of type 'NoneType' has no len()
# (pid=64370)
# (pid=64370)
# (pid=64370) During handling of the above exception, another exception occurred:
# (pid=64370)
# (pid=64370) Traceback (most recent call last):
# (pid=64370)   File "python/ray/_raylet.pyx", line 599, in ray._raylet.task_execution_handler
# (pid=64370)   File "python/ray/_raylet.pyx", line 451, in ray._raylet.execute_task
# (pid=64370)   File "python/ray/_raylet.pyx", line 556, in ray._raylet.execute_task
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/utils.py", line 102, in push_error_to_driver
# (pid=64370)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (pid=64370)   File "python/ray/_raylet.pyx", line 1682, in ray._raylet.CoreWorker.push_error
# (pid=64370) UnicodeEncodeError: 'ascii' codec can't encode characters in position 1689-1694: ordinal not in range(128)
# (pid=64370)
# (pid=64370) During handling of the above exception, another exception occurred:
# (pid=64370)
# (pid=64370) Traceback (most recent call last):
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/utils.py", line 102, in push_error_to_driver
# (pid=64370)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (pid=64370)   File "python/ray/_raylet.pyx", line 1682, in ray._raylet.CoreWorker.push_error
# (pid=64370) UnicodeEncodeError: 'ascii' codec can't encode characters in position 1751-1756: ordinal not in range(128)
# (pid=64370) Exception ignored in: 'ray._raylet.task_execution_handler'
# (pid=64370) Traceback (most recent call last):
# (pid=64370)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/utils.py", line 102, in push_error_to_driver
# (pid=64370)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (pid=64370)   File "python/ray/_raylet.pyx", line 1682, in ray._raylet.CoreWorker.push_error
# (pid=64370) UnicodeEncodeError: 'ascii' codec can't encode characters in position 1751-1756: ordinal not in range(128)
# (pid=64371) Traceback (most recent call last):
# (pid=64371)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=64371)   File "python/ray/_raylet.pyx", line 495, in ray._raylet.execute_task
# (pid=64371)   File "python/ray/_raylet.pyx", line 505, in ray._raylet.execute_task
# (pid=64371)   File "python/ray/_raylet.pyx", line 449, in ray._raylet.execute_task.function_executor
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/function_manager.py", line 556, in actor_method_executor
# (pid=64371)     return method(__ray_actor, *args, **kwargs)
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 173, in train_buffered
# (pid=64371)     result = self.train()
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 232, in train
# (pid=64371)     result = self.step()
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 366, in step
# (pid=64371)     self._report_thread_runner_error(block=True)
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 512, in _report_thread_runner_error
# (pid=64371)     raise TuneError(
# (pid=64371) ray.tune.error.TuneError: Trial raised an exception. Traceback:
# (pid=64371) Traceback (most recent call last):
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=64371)     self._entrypoint()
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=64371)     return self._trainable_func(self.config, self._status_reporter,
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=64371)     output = fn()
# (pid=64371)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=64371)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=64371)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=64371)     trainLoader = DataLoader(trainData,
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=64371)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=64371)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=64371)     return len(self.data_source)
# (pid=64371) TypeError: object of type 'NoneType' has no len()
# (pid=64371)
# (pid=64371)
# (pid=64371) During handling of the above exception, another exception occurred:
# (pid=64371)
# (pid=64371) Traceback (most recent call last):
# (pid=64371)   File "python/ray/_raylet.pyx", line 599, in ray._raylet.task_execution_handler
# (pid=64371)   File "python/ray/_raylet.pyx", line 451, in ray._raylet.execute_task
# (pid=64371)   File "python/ray/_raylet.pyx", line 556, in ray._raylet.execute_task
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/utils.py", line 102, in push_error_to_driver
# (pid=64371)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (pid=64371)   File "python/ray/_raylet.pyx", line 1682, in ray._raylet.CoreWorker.push_error
# (pid=64371) UnicodeEncodeError: 'ascii' codec can't encode characters in position 1689-1694: ordinal not in range(128)
# (pid=64371)
# (pid=64371) During handling of the above exception, another exception occurred:
# (pid=64371)
# (pid=64371) Traceback (most recent call last):
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/utils.py", line 102, in push_error_to_driver
# (pid=64371)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (pid=64371)   File "python/ray/_raylet.pyx", line 1682, in ray._raylet.CoreWorker.push_error
# (pid=64371) UnicodeEncodeError: 'ascii' codec can't encode characters in position 1751-1756: ordinal not in range(128)
# (pid=64371) Exception ignored in: 'ray._raylet.task_execution_handler'
# (pid=64371) Traceback (most recent call last):
# (pid=64371)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/utils.py", line 102, in push_error_to_driver
# (pid=64371)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (pid=64371)   File "python/ray/_raylet.pyx", line 1682, in ray._raylet.CoreWorker.push_error
# (pid=64371) UnicodeEncodeError: 'ascii' codec can't encode characters in position 1751-1756: ordinal not in range(128)
# (pid=64367) 2021-05-26 15:43:40,643	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=64367) Traceback (most recent call last):
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=64367)     self._entrypoint()
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=64367)     return self._trainable_func(self.config, self._status_reporter,
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=64367)     output = fn()
# (pid=64367)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=64367)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=64367)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=64367)     trainLoader = DataLoader(trainData,
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=64367)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=64367)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=64367)     return len(self.data_source)
# (pid=64367) TypeError: object of type 'NoneType' has no len()
# (pid=64367) Exception in thread Thread-2:
# (pid=64367) Traceback (most recent call last):
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# (pid=64367)     self.run()
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 267, in run
# (pid=64367)     raise e
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=64367)     self._entrypoint()
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=64367)     return self._trainable_func(self.config, self._status_reporter,
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=64367)     output = fn()
# (pid=64367)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=64367)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=64367)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=64367)     trainLoader = DataLoader(trainData,
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=64367)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=64367)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=64367)     return len(self.data_source)
# (pid=64367) TypeError: object of type 'NoneType' has no len()
# 2021-05-26 15:43:40,842	ERROR trial_runner.py:732 -- Trial fitTrain_15510b88: Error processing event.
# Traceback (most recent call last):
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trial_runner.py", line 702, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/ray_trial_executor.py", line 686, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 47, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/worker.py", line 1481, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=64367, ip=192.168.1.254)
#   File "python/ray/_raylet.pyx", line 505, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 449, in ray._raylet.execute_task.function_executor
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/function_manager.py", line 556, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 173, in train_buffered
#     result = self.train()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 232, in train
#     result = self.step()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 366, in step
#     self._report_thread_runner_error(block=True)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 512, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=64367, ip=192.168.1.254)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
#     self._entrypoint()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
#     output = fn()
#   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
#     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
#   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
#     trainLoader = DataLoader(trainData,
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
#     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
#     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
#     return len(self.data_source)
# TypeError: object of type 'NoneType' has no len()
# Result for fitTrain_15510b88:
#   {}
# == Status ==<br>Memory usage on this node: 11.3/16.0 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None<br>Resources requested: 1.0/12 CPUs, 0/0 GPUs, 0.0/4.85 GiB heap, 0.0/2.43 GiB objects<br>Result logdir: /Users/shaominliu/ray_results/fitTrain_2021-05-26_15-43-34<br>Number of trials: 4/50 (3 ERROR, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name       </th><th>status  </th><th>loc  </th><th>act_func_1                                   </th><th>act_func_2                                     </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  epoch</th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">      lr</th></tr>
# </thead>
# <tbody>
# <tr><td>fitTrain_155477c8</td><td>RUNNING </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;</td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td style="text-align: right;">         510</td><td style="text-align: right;">      1</td><td style="text-align: right;">          504</td><td style="text-align: right;">0.588232</td></tr>
# <tr><td>fitTrain_13090c22</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;</td><td>&lt;class &#x27;torch.nn.modules.activation.LeakyReLU&#x27;&gt;</td><td style="text-align: right;">         460</td><td style="text-align: right;">     18</td><td style="text-align: right;">          502</td><td style="text-align: right;">0.399176</td></tr>
# <tr><td>fitTrain_132a4ac2</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;   </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td style="text-align: right;">         329</td><td style="text-align: right;">     18</td><td style="text-align: right;">          412</td><td style="text-align: right;">1.00127 </td></tr>
# <tr><td>fitTrain_15510b88</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;   </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;     </td><td style="text-align: right;">         317</td><td style="text-align: right;">     21</td><td style="text-align: right;">          463</td><td style="text-align: right;">1.4189  </td></tr>
# </tbody>
# </table><br>Number of errored trials: 3<br><table>
# <thead>
# <tr><th>Trial name       </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>fitTrain_13090c22</td><td style="text-align: right;">           1</td><td>/Users/shaominliu/ray_results/fitTrain_2021-05-26_15-43-34/fitTrain_13090c22_1_act_func_1=&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;,act_func_2=&lt;class &#x27;torch.nn.modules.activation.LeakyR_2021-05-26_15-43-34/error.txt</td></tr>
# <tr><td>fitTrain_132a4ac2</td><td style="text-align: right;">           1</td><td>/Users/shaominliu/ray_results/fitTrain_2021-05-26_15-43-34/fitTrain_132a4ac2_2_act_func_1=&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;,act_func_2=&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;,ba_2021-05-26_15-43-34/error.txt</td></tr>
# <tr><td>fitTrain_15510b88</td><td style="text-align: right;">           1</td><td>/Users/shaominliu/ray_results/fitTrain_2021-05-26_15-43-34/fitTrain_15510b88_3_act_func_1=&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;,act_func_2=&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;,ba_2021-05-26_15-43-38/error.txt</td></tr>
# </tbody>
# </table><br>
# (pid=64367) Traceback (most recent call last):
# (pid=64367)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=64367)   File "python/ray/_raylet.pyx", line 495, in ray._raylet.execute_task
# (pid=64367)   File "python/ray/_raylet.pyx", line 505, in ray._raylet.execute_task
# (pid=64367)   File "python/ray/_raylet.pyx", line 449, in ray._raylet.execute_task.function_executor
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/function_manager.py", line 556, in actor_method_executor
# (pid=64367)     return method(__ray_actor, *args, **kwargs)
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 173, in train_buffered
# (pid=64367)     result = self.train()
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 232, in train
# (pid=64367)     result = self.step()
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 366, in step
# (pid=64367)     self._report_thread_runner_error(block=True)
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 512, in _report_thread_runner_error
# (pid=64367)     raise TuneError(
# (pid=64367) ray.tune.error.TuneError: Trial raised an exception. Traceback:
# (pid=64367) Traceback (most recent call last):
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=64367)     self._entrypoint()
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=64367)     return self._trainable_func(self.config, self._status_reporter,
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=64367)     output = fn()
# (pid=64367)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=64367)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=64367)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=64367)     trainLoader = DataLoader(trainData,
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=64367)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=64367)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=64367)     return len(self.data_source)
# (pid=64367) TypeError: object of type 'NoneType' has no len()
# (pid=64367)
# (pid=64367)
# (pid=64367) During handling of the above exception, another exception occurred:
# (pid=64367)
# (pid=64367) Traceback (most recent call last):
# (pid=64367)   File "python/ray/_raylet.pyx", line 599, in ray._raylet.task_execution_handler
# (pid=64367)   File "python/ray/_raylet.pyx", line 451, in ray._raylet.execute_task
# (pid=64367)   File "python/ray/_raylet.pyx", line 556, in ray._raylet.execute_task
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/utils.py", line 102, in push_error_to_driver
# (pid=64367)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (pid=64367)   File "python/ray/_raylet.pyx", line 1682, in ray._raylet.CoreWorker.push_error
# (pid=64367) UnicodeEncodeError: 'ascii' codec can't encode characters in position 1689-1694: ordinal not in range(128)
# (pid=64367)
# (pid=64367) During handling of the above exception, another exception occurred:
# (pid=64367)
# (pid=64367) Traceback (most recent call last):
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/utils.py", line 102, in push_error_to_driver
# (pid=64367)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (pid=64367)   File "python/ray/_raylet.pyx", line 1682, in ray._raylet.CoreWorker.push_error
# (pid=64367) UnicodeEncodeError: 'ascii' codec can't encode characters in position 1751-1756: ordinal not in range(128)
# (pid=64367) Exception ignored in: 'ray._raylet.task_execution_handler'
# (pid=64367) Traceback (most recent call last):
# (pid=64367)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/utils.py", line 102, in push_error_to_driver
# (pid=64367)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (pid=64367)   File "python/ray/_raylet.pyx", line 1682, in ray._raylet.CoreWorker.push_error
# (pid=64367) UnicodeEncodeError: 'ascii' codec can't encode characters in position 1751-1756: ordinal not in range(128)
# (pid=65146) 2021-05-26 15:43:41,679	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=65146) Traceback (most recent call last):
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=65146)     self._entrypoint()
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=65146)     return self._trainable_func(self.config, self._status_reporter,
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=65146)     output = fn()
# (pid=65146)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=65146)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=65146)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=65146)     trainLoader = DataLoader(trainData,
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=65146)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=65146)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=65146)     return len(self.data_source)
# (pid=65146) TypeError: object of type 'NoneType' has no len()
# (pid=65146) Exception in thread Thread-2:
# (pid=65146) Traceback (most recent call last):
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# (pid=65146)     self.run()
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 267, in run
# (pid=65146)     raise e
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=65146)     self._entrypoint()
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=65146)     return self._trainable_func(self.config, self._status_reporter,
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=65146)     output = fn()
# (pid=65146)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=65146)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=65146)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=65146)     trainLoader = DataLoader(trainData,
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=65146)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=65146)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=65146)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=65146)     return len(self.data_source)
# (pid=65146) TypeError: object of type 'NoneType' has no len()
# 2021-05-26 15:43:41,884	ERROR trial_runner.py:732 -- Trial fitTrain_155477c8: Error processing event.
# Traceback (most recent call last):
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trial_runner.py", line 702, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/ray_trial_executor.py", line 686, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 47, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/worker.py", line 1481, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=65146, ip=192.168.1.254)
#   File "python/ray/_raylet.pyx", line 505, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 449, in ray._raylet.execute_task.function_executor
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/function_manager.py", line 556, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 173, in train_buffered
#     result = self.train()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 232, in train
#     result = self.step()
# ...
# (pid=65301) Exception ignored in: 'ray._raylet.task_execution_handler'
# (pid=65301) Traceback (most recent call last):
# (pid=65301)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/utils.py", line 102, in push_error_to_driver
# (pid=65301)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (pid=65301)   File "python/ray/_raylet.pyx", line 1682, in ray._raylet.CoreWorker.push_error
# (pid=65301) UnicodeEncodeError: 'ascii' codec can't encode characters in position 1751-1756: ordinal not in range(128)
# == Status ==<br>Memory usage on this node: 11.4/16.0 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None<br>Resources requested: 2.0/12 CPUs, 0/0 GPUs, 0.0/4.85 GiB heap, 0.0/2.43 GiB objects<br>Result logdir: /Users/shaominliu/ray_results/fitTrain_2021-05-26_15-43-34<br>Number of trials: 47/50 (45 ERROR, 2 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name       </th><th>status  </th><th>loc  </th><th>act_func_1                                     </th><th>act_func_2                                     </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  epoch</th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">      lr</th></tr>
# </thead>
# <tbody>
# <tr><td>fitTrain_385c4a7a</td><td>RUNNING </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.LeakyReLU&#x27;&gt;</td><td>&lt;class &#x27;torch.nn.modules.activation.LeakyReLU&#x27;&gt;</td><td style="text-align: right;">         277</td><td style="text-align: right;">      2</td><td style="text-align: right;">          442</td><td style="text-align: right;">1.34526 </td></tr>
# <tr><td>fitTrain_38e95e6a</td><td>RUNNING </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td style="text-align: right;">         361</td><td style="text-align: right;">      4</td><td style="text-align: right;">          490</td><td style="text-align: right;">0.158215</td></tr>
# <tr><td>fitTrain_13090c22</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td>&lt;class &#x27;torch.nn.modules.activation.LeakyReLU&#x27;&gt;</td><td style="text-align: right;">         460</td><td style="text-align: right;">     18</td><td style="text-align: right;">          502</td><td style="text-align: right;">0.399176</td></tr>
# <tr><td>fitTrain_132a4ac2</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td style="text-align: right;">         329</td><td style="text-align: right;">     18</td><td style="text-align: right;">          412</td><td style="text-align: right;">1.00127 </td></tr>
# <tr><td>fitTrain_15510b88</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;     </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;     </td><td style="text-align: right;">         317</td><td style="text-align: right;">     21</td><td style="text-align: right;">          463</td><td style="text-align: right;">1.4189  </td></tr>
# <tr><td>fitTrain_155477c8</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td style="text-align: right;">         510</td><td style="text-align: right;">      1</td><td style="text-align: right;">          504</td><td style="text-align: right;">0.588232</td></tr>
# <tr><td>fitTrain_16e2a8a8</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td style="text-align: right;">         454</td><td style="text-align: right;">      1</td><td style="text-align: right;">          421</td><td style="text-align: right;">1.0154  </td></tr>
# <tr><td>fitTrain_17813c5c</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td style="text-align: right;">         294</td><td style="text-align: right;">     11</td><td style="text-align: right;">          406</td><td style="text-align: right;">1.21011 </td></tr>
# <tr><td>fitTrain_1847fda6</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;     </td><td style="text-align: right;">         336</td><td style="text-align: right;">     25</td><td style="text-align: right;">          471</td><td style="text-align: right;">0.366999</td></tr>
# <tr><td>fitTrain_18d66afa</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;     </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td style="text-align: right;">           6</td><td style="text-align: right;">     23</td><td style="text-align: right;">          426</td><td style="text-align: right;">1.18759 </td></tr>
# <tr><td>fitTrain_19ad98ae</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td style="text-align: right;">         339</td><td style="text-align: right;">     17</td><td style="text-align: right;">          416</td><td style="text-align: right;">0.735384</td></tr>
# <tr><td>fitTrain_1ae254da</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td style="text-align: right;">         415</td><td style="text-align: right;">     19</td><td style="text-align: right;">          413</td><td style="text-align: right;">0.62398 </td></tr>
# <tr><td>fitTrain_1b308d08</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;     </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;     </td><td style="text-align: right;">         373</td><td style="text-align: right;">     20</td><td style="text-align: right;">          468</td><td style="text-align: right;">1.44483 </td></tr>
# <tr><td>fitTrain_1c6d3162</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;     </td><td style="text-align: right;">         416</td><td style="text-align: right;">      5</td><td style="text-align: right;">          408</td><td style="text-align: right;">0.356969</td></tr>
# <tr><td>fitTrain_1d0ccae2</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.LeakyReLU&#x27;&gt;</td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td style="text-align: right;">         103</td><td style="text-align: right;">     19</td><td style="text-align: right;">          424</td><td style="text-align: right;">0.5391  </td></tr>
# <tr><td>fitTrain_1dd059b2</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td style="text-align: right;">         218</td><td style="text-align: right;">      8</td><td style="text-align: right;">          493</td><td style="text-align: right;">1.28743 </td></tr>
# <tr><td>fitTrain_1f33606a</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.Tanh&#x27;&gt;     </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;     </td><td style="text-align: right;">          22</td><td style="text-align: right;">      9</td><td style="text-align: right;">          491</td><td style="text-align: right;">1.17813 </td></tr>
# <tr><td>fitTrain_1fca01b4</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules.activation.ReLU&#x27;&gt;     </td><td>&lt;class &#x27;torch.nn.modules.activation.Sigmoid&#x27;&gt;  </td><td style="text-align: right;">         391</td><td style="text-align: right;">      8</td><td style="text-align: right;">          496</td><td style="text-align: right;">0.69996 </td></tr>
# <tr><td>fitTrain_208c1e0c</td><td>ERROR   </td><td>     </td><td>&lt;class &#x27;torch.nn.modules
# (pid=65300) 2021-05-26 15:44:39,109	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=65300) Traceback (most recent call last):
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=65300)     self._entrypoint()
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=65300)     return self._trainable_func(self.config, self._status_reporter,
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=65300)     output = fn()
# (pid=65300)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=65300)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=65300)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=65300)     trainLoader = DataLoader(trainData,
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=65300)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=65300)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=65300)     return len(self.data_source)
# (pid=65300) TypeError: object of type 'NoneType' has no len()
# (pid=65300) Exception in thread Thread-2:
# (pid=65300) Traceback (most recent call last):
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# (pid=65300)     self.run()
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 267, in run
# (pid=65300)     raise e
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
# (pid=65300)     self._entrypoint()
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
# (pid=65300)     return self._trainable_func(self.config, self._status_reporter,
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
# (pid=65300)     output = fn()
# (pid=65300)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
# (pid=65300)     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
# (pid=65300)   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
# (pid=65300)     trainLoader = DataLoader(trainData,
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
# (pid=65300)     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
# (pid=65300)     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# (pid=65300)   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
# (pid=65300)     return len(self.data_source)
# (pid=65300) TypeError: object of type 'NoneType' has no len()
# 2021-05-26 15:44:39,314	ERROR trial_runner.py:732 -- Trial fitTrain_385c4a7a: Error processing event.
# Traceback (most recent call last):
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trial_runner.py", line 702, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/ray_trial_executor.py", line 686, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 47, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/worker.py", line 1481, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=65300, ip=192.168.1.254)
#   File "python/ray/_raylet.pyx", line 505, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 449, in ray._raylet.execute_task.function_executor
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/_private/function_manager.py", line 556, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 173, in train_buffered
#     result = self.train()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/trainable.py", line 232, in train
#     result = self.step()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 366, in step
#     self._report_thread_runner_error(block=True)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 512, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=65300, ip=192.168.1.254)
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 248, in run
#     self._entrypoint()
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 315, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/ray/tune/function_runner.py", line 580, in _trainable_func
#     output = fn()
#   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 318, in fitTrain
#     model.optimise(cls.trainData, cls.testData, config, hyperTuning=True)
#   File "/Users/shaominliu/Documents/WorkIsMadness工作使我疯狂/2021_HolmuskInternship/Github/PyTorchExercise/ModelHelper2.py", line 159, in optimise
#     trainLoader = DataLoader(trainData,
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 266, in __init__
#     sampler = RandomSampler(dataset, generator=generator)  # type: ignore
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 102, in __init__
#     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
#   File "/Users/shaominliu/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/sampler.py", line 110, in num_samples
#     return len(self.data_source)
# TypeError: object of type 'NoneType' has no len()
# Result for fitTrain_385c4a7a:
#   {}
